# %%
import xarray as xr
import numpy as np
import pandas as pd
from datetime import date
today = date.today()

# %%
df=pd.read_csv('ALL_INDEX_AGGREGATED_Svalbard_30 min.CSV',sep = ';')
df2=df.replace(r'^\s*$', -9999999, regex=True)
df2
# Out:
#            datetime..UTC.  doy.dayfract        SZA        Lat        Lon  \
# 0     2019-06-23 18:30:00    174.788588  72.708318  78.185400  15.925788
# 1     2019-06-24 07:00:00    175.302846  60.335819  78.185400  15.925900
# 2     2019-06-24 07:30:00    175.324149  59.025746  78.185400  15.925950
# 3     2019-06-24 08:00:00    175.343659  57.944652  78.185400  15.925826
# 4     2019-06-24 08:30:00    175.363850  56.964552  78.185353  15.925823
# ...                   ...           ...        ...        ...        ...
# 8895  2021-09-30 11:00:00    273.468407  81.266593  78.185400  15.925885
# 8896  2021-09-30 11:30:00    273.489623  81.572463  78.185400  15.925965
# 8897  2021-09-30 12:00:00    273.510523  82.072112  78.185400  15.925854
# 8898  2021-09-30 12:30:00    273.531485  82.762133  78.185400  15.925800
# 8899  2021-09-30 13:00:00    273.552144  83.613958  78.185400  15.925800
#
#       A_sfm_conv  B_sfm_conv  Incoming.at.750nm.Full..W.m.2nm.1sr.1.  \
# 0              0           0                                0.053405
# 1              0           0                                0.081263
# 2              0           0                                0.094818
# 3              0           0                                0.121427
# 4              0           0                                0.139516
# ...          ...         ...                                     ...
# 8895           0           0                                0.033723
# 8896           0           0                                0.037459
# 8897           0           0                                0.034366
# 8898           0           0                                0.029969
# 8899           0           0                                0.021618
#
#       Reflected.750nm.full..W.m.2nm.1sr.1.  PAR.inc..W.m.2.  ...     REDCl  \
# 0                                 0.008198        65.167609  ...  0.291831
# 1                                 0.012654       100.092529  ...  0.286279
# 2                                 0.014469       117.355295  ...  0.284398
# 3                                 0.018275       148.973214  ...  0.278800
# 4                                 0.021105       171.677691  ...  0.281921
# ...                                    ...              ...  ...       ...
# 8895                              0.007167        34.282498  ...  0.206508
# 8896                              0.006320        37.416971  ...  0.263158
# 8897                              0.005014        35.573183  ...  0.297624
# 8898                              0.003924        31.107381  ...  0.319219
# 8899                              0.002781        24.157592  ...  0.327371
#
#           mCRI      L800      NIRv  Incoming.at.750nm..W.m.2nm.1sr.1.  \
# 0    -2.063483  0.008199  0.002531                           0.048624
# 1    -2.085478  0.012611  0.003822                           0.076780
# 2    -2.088329  0.014499  0.004376                           0.089905
# 3    -2.082644  0.018446  0.005565                           0.115172
# 4    -2.088014  0.021389  0.006500                           0.130586
# ...        ...       ...       ...                                ...
# 8895 -2.735426  0.007173  0.001436                           0.032715
# 8896 -2.353022  0.006568  0.001621                           0.035195
# 8897 -2.131776  0.005345  0.001492                           0.031726
# 8898 -2.033067  0.004256  0.001286                           0.026379
# 8899 -2.001509  0.003015  0.000929                           0.020546
#
#       Reflected.750..W.m.2nm.1sr.1.  SIF_B_ifld..mW.m.2nm.1sr.1.  \
# 0                          0.007809                    -0.031591
# 1                          0.012496                    -0.062198
# 2                          0.014283                    -0.056756
# 3                          0.018072                    -0.038649
# 4                          0.020496                    -0.062933
# ...                             ...                          ...
# 8895                       0.007357                     0.052532
# 8896                       0.006327                     0.041327
# 8897                       0.004952                     0.035430
# 8898                       0.003872                     0.024533
# 8899                       0.002944                     0.028097
#
#       SIF_A_ifld..mW.m.2nm.1sr.1.  SIF_B_sfm..mW.m.2nm.1sr.1.  \
# 0                       -0.010080                   -0.099376
# 1                       -0.024987                   -0.150137
# 2                       -0.017655                   -0.163150
# 3                       -0.022279                   -0.179135
# 4                       -0.029342                   -0.196066
# ...                           ...                         ...
# 8895                     0.013268                    0.048018
# 8896                     0.012306                    0.039186
# 8897                     0.008933                    0.027418
# 8898                     0.004349                    0.016556
# 8899                     0.003449                    0.022198
#
#       SIF_A_sfm..mW.m.2nm.1sr.1.
# 0                      -0.066517
# 1                      -0.108674
# 2                      -0.110998
# 3                      -0.121359
# 4                      -0.128573
# ...                          ...
# 8895                    0.016931
# 8896                    0.016419
# 8897                    0.010441
# 8898                    0.003227
# 8899                    0.006665
#
# [8900 rows x 29 columns]

# %%
data=df2.values
varname=df2.columns.values

# %%
time=pd.to_datetime(data[:,0])
doy=data[:,1]
SZA=data[:,2]
Lat=data[:,3]
Lon=data[:,4]
A_sfm_conv=data[:,5]
B_sfm_conv=data[:,6]
INC_750_full=data[:,7]
REF_750_full=data[:,8]
PAR_IN=data[:,9]
PAR_REF=data[:,10]
APAR=data[:,11]
NDVI=data[:,12]
PRI=data[:,13]
MTCI=data[:,14]
SR=data[:,15]
EVI=data[:,16]
REP=data[:,17]
TCARI=data[:,18]
REDCl=data[:,19]
mCRI=data[:,20]
L800=data[:,21]
NIRv=data[:,22]
INC_750=data[:,23]
REF_750=data[:,24]
SIF_B_ifld=data[:,25]
SIF_A_ifld=data[:,26]
SIF_B_sfm=data[:,27]
SIF_A_sfm=data[:,28]

# %%
ds=xr.Dataset(
    data_vars=dict(
        doy=(["time"], doy),
        SZA=(["time"], SZA,{"units": "none"}),
        A_sfm_conv=(["time"], A_sfm_conv),
        B_sfm_conv=(["time"], B_sfm_conv),
        INC_750_full=(["time"], INC_750_full,{"units": "W m2 nm-1 sr-1"}),
        REF_750_full=(["time"], REF_750_full,{"units": "W m2 nm-1 sr-1"}),
        PAR_IN=(["time"], PAR_IN, {"units": "W m-2"}),
        PAR_REF=(["time"], PAR_REF,{"units": "W m-2"}),
        APAR=(["time"], APAR,{"units": "umol m-2 s-1"}),
        NDVI=(["time"], NDVI),
        PRI=(["time"], PRI),
        MTCI=(["time"], MTCI),
        SR=(["time"], SR),
        EVI=(["time"], EVI),
        REP=(["time"], REP),
        TCARI=(["time"], TCARI),
        REDCl=(["time"], REDCl),
        mCRI=(["time"], mCRI),
        L800=(["time"], L800),
        NIRv=(["time"], NIRv),
        INC_750=(["time"], INC_750,{"units": "W m2 nm-1 sr-1"}),
        REF_750=(["time"], REF_750,{"units": "W m2 nm-1 sr-1"}),
        SIF_B_ifld=(["time"], SIF_B_ifld,{"units": "mW m-2 nm-1 sr-1"}),
        SIF_A_ifld=(["time"], SIF_A_ifld,{"units": "mW m-2 nm-1 sr-1"}),
        SIF_B_sfm=(["time"], SIF_B_sfm,{"units": "mW m-2 nm-1 sr-1"}),
        SIF_A_sfm=(["time"], SIF_A_sfm,{"units": "mW m-2 nm-1 sr-1"})
    ),
    coords=dict(
    lon=(["lon"], Lon,{"units": "Degrees East"}),
    lat=(["lat"], Lat,{"units": "Degrees North"}),
    time=time,
    reference_time=time[0],
)
)

# %%
ds.attrs['id']='DOI needed'

ds.attrs['naming_authority']='Norsk Meteorologisk Institutt'

ds.attrs['title'] = "ALL_INDEX_AGGREGATED_Svalbard_30_min"

ds.attrs['summary']='needed'

ds.attrs['keywords']='spectroscopy, observations, Svalbard'
ds.attrs['keywords_vocabulary']='needed'

ds.attrs['geospatial_lat_min']=np.min(Lat)
ds.attrs['geospatial_lat_max']=np.max(Lat)
ds.attrs['geospatial_lon_miN']=np.min(Lon)
ds.attrs['geospatial_lon_max']=np.max(Lon)

ds.attrs['time_coverage_start']=str(np.min(time))
ds.attrs['time_coverage_end']=str(np.max(time))

ds.attrs['Conventions']='CF 1.11'

ds.attrs['history']='I need the history'
ds.attrs['source']='Observations made with FloX a spectroscopy system for the unsupervised retrieval of Sun-Induced-Fluorescence (SIF) and spectrally resolved reflectance. The instrument consists of two high performance spectrometers contained in a temperature controlled compartment. One fine resolution spectrometer (FLUO) covers the range from 650 nm to 800 nm observing the SIF signal within the O2A and O2B Fraunhofer Absorption lines. The second spectrometer (FULL) covers the range from 400 to 1000 nm. Each spectrometer measures the down-welling irradiance and the upwelling radiance using two optical fibers. A rugged weatherproof case and an autonomous acquisition protocol including data storage allows continuous observation of plant canopies over long periods.'

ds.attrs['processing_level']='LEVEL 2'

ds.attrs['date_created']=str(today)

ds.attrs['creator_type']='Group'
ds.attrs['creator_institution']='Norsk Meteorologisk Institutt'
ds.attrs['creator_name']='I need the name'
ds.attrs['creator_email']='I need the email'
ds.attrs['creator_url']='I need the url'

ds.attrs['institution']='Norsk Meteorologisk Institutt'

ds.attrs['publisher_name']='I need the name'
ds.attrs['publisher_email']='I need the email'
ds.attrs['publisher_url']='I need the url'

ds.attrs['project']='Needed'

ds.attrs['platform']='FloX spectroscopy'
ds.attrs['platform_vocabulary']='Needed'

ds.attrs['instrument']='FloX'
ds.attrs['instrument_vocabulary']='Needed'

ds.attrs['references']='Needed'

ds.attrs['license']='None'

ds.attrs['iso_topic_category']='Needed'
ds.attrs['activity_type']='in situ observation'
ds.attrs['operational_status']='needed'

# %%
comp = dict(zlib=True, complevel=5)
encoding = {var: comp for var in ds.data_vars}
ds.to_netcdf('ALL_INDEX_AGGREGATED_Svalbard_30_min.nc', encoding=encoding)
