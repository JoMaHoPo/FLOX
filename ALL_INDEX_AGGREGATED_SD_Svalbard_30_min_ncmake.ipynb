# %%
import xarray as xr
import numpy as np
import pandas as pd
from datetime import date
today = date.today()

# %%
df=pd.read_csv('ALL_INDEX_AGGREGATED_SD_Svalbard_30 min.CSV',sep = ';')
df2=df.replace(r'^\s*$', -9999999, regex=True)
df2
# Out:
#            datetime..UTC.         doy.dayfract                SZA  \
# 0     2019-06-23 18:30:00  0.00204320929370688  0.126143212204724
# 1     2019-06-24 07:00:00  0.00582963123968975  0.374293450048669
# 2     2019-06-24 07:30:00  0.00541325988024326  0.316967135228387
# 3     2019-06-24 08:00:00  0.00602855221965909  0.315117104739782
# 4     2019-06-24 08:30:00  0.00603999457355419  0.269086571170439
# ...                   ...                  ...                ...
# 8895  2021-09-30 11:00:00  0.00628807943811112  0.060811117404633
# 8896  2021-09-30 11:30:00  0.00615027203901319  0.118747781680981
# 8897  2021-09-30 12:00:00  0.00615027203901034  0.175518745977569
# 8898  2021-09-30 12:30:00  0.00619210415336668  0.230664134827107
# 8899  2021-09-30 13:00:00  0.00597572031920633  0.269796986125371
#
#                        Lat                   Lon A_sfm_conv B_sfm_conv  \
# 0                        0   3.5355339059245e-05          0          0
# 1                        0                     0          0          0
# 2                        0   5.0990195135809e-05          0          0
# 3                        0  4.44802722973533e-05          0          0
# 4     5.07416263421769e-05  4.30183067151074e-05          0          0
# ...                    ...                   ...        ...        ...
# 8895                     0  9.48833441801407e-05          0          0
# 8896                     0  4.85164524036453e-05          0          0
# 8897                     0  5.08391127440609e-05          0          0
# 8898                     0                     0          0          0
# 8899                     0                     0          0          0
#
#      Incoming.at.750nm.Full..W.m.2nm.1sr.1.  \
# 0                      0.000395421911068854
# 1                       0.00331454135772368
# 2                        0.0065718380779853
# 3                       0.00497517847755534
# 4                       0.00729045734176401
# ...                                     ...
# 8895                    0.00286742356098587
# 8896                    0.00150931440421532
# 8897                    0.00285573553992673
# 8898                    0.00204883449897444
# 8899                    0.00270788458580987
#
#      Reflected.750nm.full..W.m.2nm.1sr.1.    PAR.inc..W.m.2.  ...  \
# 0                    4.34432250593895e-05  0.701892393074667  ...
# 1                    0.000488615759730953   4.00243325621015  ...
# 2                     0.00100463238646996   7.85860172141198  ...
# 3                    0.000634922958528715   6.18718442478812  ...
# 4                     0.00120892857461681   8.77722873594467  ...
# ...                                   ...                ...  ...
# 8895                 0.000366892222209369   2.11592528231475  ...
# 8896                 0.000503944895103577  0.907395062606479  ...
# 8897                 0.000566373839833395   1.96633994628509  ...
# 8898                   0.0003416751832704    2.0532342173925  ...
# 8899                 0.000324060584345572   2.13909588705073  ...
#
#                     REDCl                mCRI                  L800  \
# 0     0.00541334809124261  0.0167238337268235  2.73978008716976e-05
# 1      0.0067219934304292  0.0154910856592882  0.000500167422835687
# 2     0.00618517153753031   0.015836410729628   0.00104321891036708
# 3     0.00577202120670776  0.0148466803401078  0.000668956771088692
# 4     0.00463397190055815  0.0107776145262351   0.00122787669657675
# ...                   ...                 ...                   ...
# 8895   0.0164969971870028   0.128360450375134  0.000370776914035982
# 8896   0.0145058583560759  0.0909124763761532  0.000467512888406147
# 8897   0.0102292387050823  0.0457541513605722  0.000565264139550793
# 8898   0.0100292330802985  0.0229823410366776  0.000367585836257718
# 8899  0.00729246166956444  0.0168836667307984  0.000361917664373321
#
#                       NIRv Incoming.at.750nm..W.m.2nm.1sr.1.  \
# 0     1.58656608120809e-05              0.000344335381631773
# 1     0.000146798774156235               0.00301851701680376
# 2     0.000318937212275368               0.00647867537254714
# 3     0.000206387409976263               0.00469300901103148
# 4     0.000385628410669296               0.00644479117715457
# ...                    ...                               ...
# 8895    0.0001293166269902               0.00251200561461989
# 8896  6.91051526558009e-05               0.00142688817667026
# 8897  0.000120304181109949               0.00272129742736209
# 8898  9.69217938020372e-05               0.00209481470978226
# 8899  0.000112329512383203               0.00132348184618821
#
#      Reflected.750..W.m.2nm.1sr.1. SIF_B_ifld..mW.m.2nm.1sr.1.  \
# 0             0.000228443425813429          0.0146861943432095
# 1             0.000453599671302172          0.0324750482291275
# 2              0.00102035890848291          0.0361114231600751
# 3             0.000635978823316021          0.0313010926186906
# 4              0.00119818788795168          0.0520554792026549
# ...                            ...                         ...
# 8895          0.000379077221531788          0.0212070877496099
# 8896          0.000542575295523211          0.0163573204142644
# 8897          0.000568213153617668          0.0198772955340899
# 8898          0.000330382454010341          0.0140911886894227
# 8899          0.000206640776804976         0.00862559392970651
#
#      SIF_A_ifld..mW.m.2nm.1sr.1. SIF_B_sfm..mW.m.2nm.1sr.1.  \
# 0             0.0116671227974748         0.0145953501047913
# 1            0.00878974312821489         0.0156181042908571
# 2             0.0122042125276667         0.0224303284846328
# 3             0.0149964671551771         0.0222545001346077
# 4             0.0173149359336299         0.0257543062601485
# ...                          ...                        ...
# 8895         0.00700893400021773        0.00961298584644574
# 8896         0.00621801828636189        0.00720935203836257
# 8897         0.00413998826902553        0.00662900688934801
# 8898          0.0049504545359168        0.00768927246194945
# 8899         0.00405336695973614        0.00534833300505868
#
#      SIF_A_sfm..mW.m.2nm.1sr.1.
# 0           0.00583283884785349
# 1            0.0054125764155612
# 2            0.0047376980528844
# 3           0.00808618149110957
# 4              0.00718784154872
# ...                         ...
# 8895        0.00288936376982416
# 8896        0.00224488125697497
# 8897        0.00288629485011143
# 8898        0.00345398425853113
# 8899        0.00272352684604963
#
# [8900 rows x 29 columns]

# %%
data=df2.values
varname=df2.columns.values

# %%
time=pd.to_datetime(data[:,0])
doy=data[:,1]
SZA=data[:,2]
Lat=data[:,3]
Lon=data[:,4]
A_sfm_conv=data[:,5]
B_sfm_conv=data[:,6]
INC_750_full=data[:,7]
REF_750_full=data[:,8]
PAR_IN=data[:,9]
PAR_REF=data[:,10]
APAR=data[:,11]
NDVI=data[:,12]
PRI=data[:,13]
MTCI=data[:,14]
SR=data[:,15]
EVI=data[:,16]
REP=data[:,17]
TCARI=data[:,18]
REDCl=data[:,19]
mCRI=data[:,20]
L800=data[:,21]
NIRv=data[:,22]
INC_750=data[:,23]
REF_750=data[:,24]
SIF_B_ifld=data[:,25]
SIF_A_ifld=data[:,26]
SIF_B_sfm=data[:,27]
SIF_A_sfm=data[:,28]

# %%
ds=xr.Dataset(
    data_vars=dict(
        doy=(["time"], doy),
        SZA=(["time"], SZA,{"units": "none"}),
        A_sfm_conv=(["time"], A_sfm_conv),
        B_sfm_conv=(["time"], B_sfm_conv),
        INC_750_full=(["time"], INC_750_full,{"units": "W m2 nm-1 sr-1"}),
        REF_750_full=(["time"], REF_750_full,{"units": "W m2 nm-1 sr-1"}),
        PAR_IN=(["time"], PAR_IN, {"units": "W m-2"}),
        PAR_REF=(["time"], PAR_REF,{"units": "W m-2"}),
        APAR=(["time"], APAR,{"units": "umol m-2 s-1"}),
        NDVI=(["time"], NDVI),
        PRI=(["time"], PRI),
        MTCI=(["time"], MTCI),
        SR=(["time"], SR),
        EVI=(["time"], EVI),
        REP=(["time"], REP),
        TCARI=(["time"], TCARI),
        REDCl=(["time"], REDCl),
        mCRI=(["time"], mCRI),
        L800=(["time"], L800),
        NIRv=(["time"], NIRv),
        INC_750=(["time"], INC_750,{"units": "W m2 nm-1 sr-1"}),
        REF_750=(["time"], REF_750,{"units": "W m2 nm-1 sr-1"}),
        SIF_B_ifld=(["time"], SIF_B_ifld,{"units": "mW m-2 nm-1 sr-1"}),
        SIF_A_ifld=(["time"], SIF_A_ifld,{"units": "mW m-2 nm-1 sr-1"}),
        SIF_B_sfm=(["time"], SIF_B_sfm,{"units": "mW m-2 nm-1 sr-1"}),
        SIF_A_sfm=(["time"], SIF_A_sfm,{"units": "mW m-2 nm-1 sr-1"})
    ),
    coords=dict(
    lon=(["lon"], Lon,{"units": "Degrees East"}),
    lat=(["lat"], Lat,{"units": "Degrees North"}),
    time=time,
    reference_time=time[0],
)
)

# %%
ds.attrs['id']='DOI needed'

ds.attrs['naming_authority']='Norsk Meteorologisk Institutt'

ds.attrs['title'] = "ALL_INDEX_AGGREGATED_SD_Svalbard_30 min"

ds.attrs['summary']='needed'

ds.attrs['keywords']='spectroscopy, observations, Svalbard'
ds.attrs['keywords_vocabulary']='needed'

ds.attrs['geospatial_lat_min']=np.min(Lat)
ds.attrs['geospatial_lat_max']=np.max(Lat)
ds.attrs['geospatial_lon_miN']=np.min(Lon)
ds.attrs['geospatial_lon_max']=np.max(Lon)

ds.attrs['time_coverage_start']=str(np.min(time))
ds.attrs['time_coverage_end']=str(np.max(time))

ds.attrs['Conventions']='CF 1.11'

ds.attrs['history']='I need the history'
ds.attrs['source']='Observations made with FloX a spectroscopy system for the unsupervised retrieval of Sun-Induced-Fluorescence (SIF) and spectrally resolved reflectance. The instrument consists of two high performance spectrometers contained in a temperature controlled compartment. One fine resolution spectrometer (FLUO) covers the range from 650 nm to 800 nm observing the SIF signal within the O2A and O2B Fraunhofer Absorption lines. The second spectrometer (FULL) covers the range from 400 to 1000 nm. Each spectrometer measures the down-welling irradiance and the upwelling radiance using two optical fibers. A rugged weatherproof case and an autonomous acquisition protocol including data storage allows continuous observation of plant canopies over long periods.'

ds.attrs['processing_level']='LEVEL 2'

ds.attrs['date_created']=str(today)

ds.attrs['creator_type']='Group'
ds.attrs['creator_institution']='Norsk Meteorologisk Institutt'
ds.attrs['creator_name']='I need the name'
ds.attrs['creator_email']='I need the email'
ds.attrs['creator_url']='I need the url'

ds.attrs['institution']='Norsk Meteorologisk Institutt'

ds.attrs['publisher_name']='I need the name'
ds.attrs['publisher_email']='I need the email'
ds.attrs['publisher_url']='I need the url'

ds.attrs['project']='Needed'

ds.attrs['platform']='FloX spectroscopy'
ds.attrs['platform_vocabulary']='Needed'

ds.attrs['instrument']='FloX'
ds.attrs['instrument_vocabulary']='Needed'

ds.attrs['references']='Needed'

ds.attrs['license']='None'

ds.attrs['iso_topic_category']='Needed'
ds.attrs['activity_type']='in situ observation'
ds.attrs['operational_status']='needed'

# %%
comp = dict(zlib=True, complevel=5)
encoding = {var: comp for var in ds.data_vars}
ds.to_netcdf('ALL_INDEX_AGGREGATED_SD_Svalbard_30 min.nc', encoding=encoding)
